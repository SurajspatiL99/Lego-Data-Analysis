# %% [markdown]
# # LEGO Data Analysis - Rebrickable

# %% [markdown]
# The dataset is from https://rebrickable.com/downloads/.
#
# From the Rebrickable website - "The LEGO Parts/Sets/Colors and Inventories of every official LEGO set in the Rebrickable database is available for download as csv files here. These files are automatically updated daily. If you need more details, you can use the API which provides real-time data, but has rate limits that prevent bulk downloading of data."
#
# Rebrickable provides this database to be used for any purpose.

# %% [markdown]
# ## LEGO Data Model

# %% [markdown]
# ![downloads_schema_v3.png](attachment:downloads_schema_v3.png)

# %% [markdown]
# #### Importing Libraries

# %%
#pip install pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Getting Data

# %%
sets = pd.read_csv('sets.csv')
sets
# Out:
#            set_num                             name  year  theme_id  \
# 0            001-1                            Gears  1965         1
# 1           0011-2                Town Mini-Figures  1979        67
# 2           0011-3       Castle 2 for 1 Bonus Offer  1987       199
# 3           0012-1               Space Mini-Figures  1979       143
# 4           0013-1               Space Mini-Figures  1979       143
# ...            ...                              ...   ...       ...
# 21270      XWING-1              Mini X-Wing Fighter  2019       158
# 21271      XWING-2                X-Wing Trench Run  2019       158
# 21272  YODACHRON-1  Yoda Chronicles Promotional Set  2013       158
# 21273   YTERRIER-1                Yorkshire Terrier  2018       598
# 21274     ZX8000-1             ZX 8000 LEGO Sneaker  2020       501
#
#        num_parts                                            img_url
# 0             43   https://cdn.rebrickable.com/media/sets/001-1.jpg
# 1             12  https://cdn.rebrickable.com/media/sets/0011-2.jpg
# 2              0  https://cdn.rebrickable.com/media/sets/0011-3.jpg
# 3             12  https://cdn.rebrickable.com/media/sets/0012-1.jpg
# 4             12  https://cdn.rebrickable.com/media/sets/0013-1.jpg
# ...          ...                                                ...
# 21270         60  https://cdn.rebrickable.com/media/sets/xwing-1...
# 21271         52  https://cdn.rebrickable.com/media/sets/xwing-2...
# 21272        413  https://cdn.rebrickable.com/media/sets/yodachr...
# 21273          0  https://cdn.rebrickable.com/media/sets/yterrie...
# 21274          0  https://cdn.rebrickable.com/media/sets/zx8000-...
#
# [21275 rows x 6 columns]

# %%
themes = pd.read_csv('themes.csv')
themes
# Out:
#       id                name  parent_id
# 0      1             Technic        NaN
# 1      3         Competition        1.0
# 2      4      Expert Builder        1.0
# 3     16          RoboRiders        1.0
# 4     17      Speed Slammers        1.0
# ..   ...                 ...        ...
# 460  745          Disney 100      535.0
# 461  746       Database Sets      301.0
# 462  747  Sonic The Hedgehog        NaN
# 463  748  Gabby’s Dollshouse        NaN
# 464  749            Dreamzzz        NaN
#
# [465 rows x 3 columns]

# %% [markdown]
# #### Display Top 10 Rows of the sets dataset

# %%
sets.head(10)
# Out:
#        set_num                                   name  year  theme_id  \
# 0        001-1                                  Gears  1965         1
# 1       0011-2                      Town Mini-Figures  1979        67
# 2       0011-3             Castle 2 for 1 Bonus Offer  1987       199
# 3       0012-1                     Space Mini-Figures  1979       143
# 4       0013-1                     Space Mini-Figures  1979       143
# 5       0014-1                     Space Mini-Figures  1979       143
# 6       0015-1                     Space Mini-Figures  1979       143
# 7       0016-1                    Castle Mini Figures  1979       189
# 8        002-1         4.5V Samsonite Gears Motor Set  1965         1
# 9  002253963-1  Legend of Chima: Corbeaux et Gorilles  2013       497
#
#    num_parts                                            img_url
# 0         43   https://cdn.rebrickable.com/media/sets/001-1.jpg
# 1         12  https://cdn.rebrickable.com/media/sets/0011-2.jpg
# 2          0  https://cdn.rebrickable.com/media/sets/0011-3.jpg
# 3         12  https://cdn.rebrickable.com/media/sets/0012-1.jpg
# 4         12  https://cdn.rebrickable.com/media/sets/0013-1.jpg
# 5          2  https://cdn.rebrickable.com/media/sets/0014-1.jpg
# 6         18  https://cdn.rebrickable.com/media/sets/0015-1.jpg
# 7         15  https://cdn.rebrickable.com/media/sets/0016-1.jpg
# 8          3   https://cdn.rebrickable.com/media/sets/002-1.jpg
# 9          4  https://cdn.rebrickable.com/media/sets/0022539...

# %% [markdown]
# #### Display Last 10 Rows of the sets dataset

# %%
sets.tail(10)
# Out:
#            set_num                              name  year  theme_id  \
# 21265   XBOXGAME-1   Batman the Videogame - Xbox 360  2008       742
# 21266   XBOXGAME-2        Bionicle Heroes - Xbox 360  2006       742
# 21267   XBOXGAME-3      DC Super-Villains - Xbox One  2018       742
# 21268   XBOXGAME-9  Star Wars: The Video Game - Xbox  2005       742
# 21269   XMASTREE-1                    Christmas Tree  2019       410
# 21270      XWING-1               Mini X-Wing Fighter  2019       158
# 21271      XWING-2                 X-Wing Trench Run  2019       158
# 21272  YODACHRON-1   Yoda Chronicles Promotional Set  2013       158
# 21273   YTERRIER-1                 Yorkshire Terrier  2018       598
# 21274     ZX8000-1              ZX 8000 LEGO Sneaker  2020       501
#
#        num_parts                                            img_url
# 21265          0  https://cdn.rebrickable.com/media/sets/xboxgam...
# 21266          0  https://cdn.rebrickable.com/media/sets/xboxgam...
# 21267          0  https://cdn.rebrickable.com/media/sets/xboxgam...
# 21268          0  https://cdn.rebrickable.com/media/sets/xboxgam...
# 21269         26  https://cdn.rebrickable.com/media/sets/xmastre...
# 21270         60  https://cdn.rebrickable.com/media/sets/xwing-1...
# 21271         52  https://cdn.rebrickable.com/media/sets/xwing-2...
# 21272        413  https://cdn.rebrickable.com/media/sets/yodachr...
# 21273          0  https://cdn.rebrickable.com/media/sets/yterrie...
# 21274          0  https://cdn.rebrickable.com/media/sets/zx8000-...

# %% [markdown]
# #### Check Datatype of Each Column

# %%
sets.dtypes
# Out:
# set_num      object
# name         object
# year          int64
# theme_id      int64
# num_parts     int64
# img_url      object
# dtype: object

# %% [markdown]
# #### Check NULL Values in Sets

# %%
sets.isnull().sum()
# Out:
# set_num      0
# name         0
# year         0
# theme_id     0
# num_parts    0
# img_url      0
# dtype: int64

# %%
themes.isnull().sum()
# Out:
# id             0
# name           0
# parent_id    144
# dtype: int64

# %% [markdown]
# #### How many Rows and Columns are there in our dataset

# %%
sets.shape
# Out:
# (21275, 6)

# %%
len(sets.columns)
# Out:
# 6

# %%
len(sets)
# Out:
# 21275

# %%
sets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21275 entries, 0 to 21274
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   set_num    21275 non-null  object
#  1   name       21275 non-null  object
#  2   year       21275 non-null  int64
#  3   theme_id   21275 non-null  int64
#  4   num_parts  21275 non-null  int64
#  5   img_url    21275 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 997.4+ KB

# %% [markdown]
# ## MERGE DATA
# #### Joining the two datasets to answer questions

# %%
sets_themes = pd.merge(sets, themes, how = 'left', left_on = 'theme_id', right_on = 'id', suffixes = ('_sets', '_themes'))

# %%
sets_themes.head()
# Out:
#   set_num                   name_sets  year  theme_id  num_parts  \
# 0   001-1                       Gears  1965         1         43
# 1  0011-2           Town Mini-Figures  1979        67         12
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987       199          0
# 3  0012-1          Space Mini-Figures  1979       143         12
# 4  0013-1          Space Mini-Figures  1979       143         12
#
#                                              img_url   id   name_themes  \
# 0   https://cdn.rebrickable.com/media/sets/001-1.jpg    1       Technic
# 1  https://cdn.rebrickable.com/media/sets/0011-2.jpg   67  Classic Town
# 2  https://cdn.rebrickable.com/media/sets/0011-3.jpg  199  Lion Knights
# 3  https://cdn.rebrickable.com/media/sets/0012-1.jpg  143  Supplemental
# 4  https://cdn.rebrickable.com/media/sets/0013-1.jpg  143  Supplemental
#
#    parent_id
# 0        NaN
# 1       50.0
# 2      186.0
# 3      126.0
# 4      126.0

# %%
sets_themes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21275 entries, 0 to 21274
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   set_num      21275 non-null  object
#  1   name_sets    21275 non-null  object
#  2   year         21275 non-null  int64
#  3   theme_id     21275 non-null  int64
#  4   num_parts    21275 non-null  int64
#  5   img_url      21275 non-null  object
#  6   id           21275 non-null  int64
#  7   name_themes  21275 non-null  object
#  8   parent_id    11586 non-null  float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 1.6+ MB

# %%
sets_themes.columns
# Out:
# Index(['set_num', 'name_sets', 'year', 'theme_id', 'num_parts', 'img_url',
#        'id', 'name_themes', 'parent_id'],
#       dtype='object')

# %% [markdown]
# ### Now Let's Answer some Questions

# %% [markdown]
# #### 1.) What is the total number of parts per theme

# %%
Num_Parts_per_Theme = sets_themes.groupby('name_themes').sum().reset_index()
Num_Parts_per_Theme = Num_Parts_per_Theme[['name_themes', 'num_parts']].sort_values('num_parts', ascending = False)
Num_Parts_per_Theme
# Out:
#                      name_themes  num_parts
# 323                      Technic     245912
# 308                    Star Wars     237673
# 125                      Friends     120683
# 220                      Ninjago     118258
# 353    Ultimate Collector Series     100576
# ..                           ...        ...
# 238       Posters and Art Prints          0
# 25          Bag and Luggage Tags          0
# 256  Role Play Toys and Costumes          0
# 130           Gabby’s Dollshouse          0
# 101                     Dreamzzz          0
#
# [379 rows x 2 columns]

# %%
Num_Parts_per_Theme.head(10).plot(kind='bar', x='name_themes', y='num_parts')
# Out:
# <AxesSubplot:xlabel='name_themes'>

# %% [markdown]
# #### 2.) What is the total number of parts per year

# %%
Num_Parts_per_Year = sets_themes.groupby('year').sum().reset_index()
Num_Parts_per_Year = Num_Parts_per_Year[['year', 'num_parts']].sort_values('num_parts', ascending = False)
Num_Parts_per_Year
# Out:
#     year  num_parts
# 71  2022     280744
# 70  2021     265473
# 69  2020     212088
# 68  2019     192036
# 66  2017     178717
# ..   ...        ...
# 5   1956        295
# 3   1954        117
# 8   1959         65
# 2   1953         50
# 1   1950          6
#
# [73 rows x 2 columns]

# %%
Num_Parts_per_Year.sort_values('num_parts', ascending = True).plot(kind='line', x= 'year', y='num_parts')
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# #### 3.) How many sets where created in each Century in the dataset

# %% [markdown]
# We have to add Century as a derived column to the sets_themes dataset

# %%
unique_year = sets_themes['year'].unique()
unique_year.sort()
unique_year
# Out:
# array([1949, 1950, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961,
#        1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972,
#        1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983,
#        1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994,
#        1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005,
#        2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
#        2017, 2018, 2019, 2020, 2021, 2022, 2023], dtype=int64)

# %%
sets_themes['year'] > 2000

sets_themes['Century'] = np.where(sets_themes['year'] > 2000, '21st_Century', '20th_Century')

# %%
sets_themes
# Out:
#            set_num                        name_sets  year  theme_id  \
# 0            001-1                            Gears  1965         1
# 1           0011-2                Town Mini-Figures  1979        67
# 2           0011-3       Castle 2 for 1 Bonus Offer  1987       199
# 3           0012-1               Space Mini-Figures  1979       143
# 4           0013-1               Space Mini-Figures  1979       143
# ...            ...                              ...   ...       ...
# 21270      XWING-1              Mini X-Wing Fighter  2019       158
# 21271      XWING-2                X-Wing Trench Run  2019       158
# 21272  YODACHRON-1  Yoda Chronicles Promotional Set  2013       158
# 21273   YTERRIER-1                Yorkshire Terrier  2018       598
# 21274     ZX8000-1             ZX 8000 LEGO Sneaker  2020       501
#
#        num_parts                                            img_url   id  \
# 0             43   https://cdn.rebrickable.com/media/sets/001-1.jpg    1
# 1             12  https://cdn.rebrickable.com/media/sets/0011-2.jpg   67
# 2              0  https://cdn.rebrickable.com/media/sets/0011-3.jpg  199
# 3             12  https://cdn.rebrickable.com/media/sets/0012-1.jpg  143
# 4             12  https://cdn.rebrickable.com/media/sets/0013-1.jpg  143
# ...          ...                                                ...  ...
# 21270         60  https://cdn.rebrickable.com/media/sets/xwing-1...  158
# 21271         52  https://cdn.rebrickable.com/media/sets/xwing-2...  158
# 21272        413  https://cdn.rebrickable.com/media/sets/yodachr...  158
# 21273          0  https://cdn.rebrickable.com/media/sets/yterrie...  598
# 21274          0  https://cdn.rebrickable.com/media/sets/zx8000-...  501
#
#         name_themes  parent_id       Century
# 0           Technic        NaN  20th_Century
# 1      Classic Town       50.0  20th_Century
# 2      Lion Knights      186.0  20th_Century
# 3      Supplemental      126.0  20th_Century
# 4      Supplemental      126.0  20th_Century
# ...             ...        ...           ...
# 21270     Star Wars        NaN  21st_Century
# 21271     Star Wars        NaN  21st_Century
# 21272     Star Wars        NaN  21st_Century
# 21273   Promotional        NaN  21st_Century
# 21274          Gear        NaN  21st_Century
#
# [21275 rows x 10 columns]

# %%
Num_set_per_Century = sets_themes.groupby('Century').count().reset_index()
Num_set_per_Century [['Century', 'set_num']]
# Out:
#         Century  set_num
# 0  20th_Century     5044
# 1  21st_Century    16231

# %% [markdown]
# #### 4.) What percentage of sets ever released in the 21st Century were Trains Themed

# %%
Century_21_Data = sets_themes[ sets_themes['Century'] == '21st_Century']
Train = Century_21_Data[ Century_21_Data['name_themes'].str.contains('Train')]

# %%
Century_21_Data.shape[0]
# Out:
# 16231

# %%
Train.shape[0]
# Out:
# 69

# %%
Train.shape[0] / Century_21_Data.shape[0] * 100
# Out:
# 0.42511243915963276

# %% [markdown]
# #### 5.) What percentage of sets ever released in the 21st Century were Disney Themed

# %%
Disney = Century_21_Data[ Century_21_Data['name_themes'].str.contains('Disney')]
Disney
# Out:
#                    set_num                   name_sets  year  theme_id  \
# 449                10509-1              Dusty and Chug  2013       627
# 451                10510-1       Ripslinger's Air Race  2013       627
# 452                10511-1     Skipper's Flight School  2013       627
# 456                10515-1     Ariel's Undersea Castle  2013       640
# 457                10516-1   Ariel's Magical Boat Ride  2012       640
# ...                    ...                         ...   ...       ...
# 20052              BELLE-1              Belle's Castle  2016       579
# 20124  CINDERELLASCASTLE-1         Cinderella's Castle  2017       608
# 21044               ROSE-1  The Beast's Enchanted Rose  2017       608
# 21174       TRUCOGSWORTH-1                   Cogsworth  2016       608
# 21185         TRULUMIERE-1                     Lumiere  2016       608
#
#        num_parts                                            img_url   id  \
# 449           16  https://cdn.rebrickable.com/media/sets/10509-1...  627
# 451           40  https://cdn.rebrickable.com/media/sets/10510-1...  627
# 452           53  https://cdn.rebrickable.com/media/sets/10511-1...  627
# 456           39  https://cdn.rebrickable.com/media/sets/10515-1...  640
# 457           30  https://cdn.rebrickable.com/media/sets/10516-1...  640
# ...          ...                                                ...  ...
# 20052         72  https://cdn.rebrickable.com/media/sets/belle-1...  579
# 20124        102  https://cdn.rebrickable.com/media/sets/cindere...  608
# 21044          0  https://cdn.rebrickable.com/media/sets/rose-1.jpg  608
# 21174         48  https://cdn.rebrickable.com/media/sets/trucogs...  608
# 21185         24  https://cdn.rebrickable.com/media/sets/trulumi...  608
#
#            name_themes  parent_id       Century
# 449      Disney Planes      504.0  21st_Century
# 451      Disney Planes      504.0  21st_Century
# 452      Disney Planes      504.0  21st_Century
# 456    Disney Princess      504.0  21st_Century
# 457    Disney Princess      504.0  21st_Century
# ...                ...        ...           ...
# 20052  Disney Princess        NaN  21st_Century
# 20124           Disney        NaN  21st_Century
# 21044           Disney        NaN  21st_Century
# 21174           Disney        NaN  21st_Century
# 21185           Disney        NaN  21st_Century
#
# [226 rows x 10 columns]

# %%
Disney.shape[0]
# Out:
# 226

# %%
Disney.shape[0] / Century_21_Data.shape[0] * 100
# Out:
# 1.3923972644938698

# %% [markdown]
# #### 6.) What is the popular theme by year in terms of sets released in the 21st Century

# %%
Popular_Theme_per_Year = Century_21_Data.groupby(['year', 'name_themes']).count().reset_index()
Popular_Theme_per_Year = Popular_Theme_per_Year[['year', 'name_themes', 'set_num']].sort_values('set_num', ascending = False)
Popular_Theme_per_Year.drop_duplicates('year').sort_values('year', ascending = False)
# Out:
#       year        name_themes  set_num
# 1714  2023            Friends       43
# 1617  2022              Books       80
# 1559  2021               Gear      149
# 1467  2020            Friends       59
# 1426  2019  The LEGO Movie II       64
# 1330  2018          Star Wars       69
# 1244  2017          Star Wars       64
# 1158  2016          Star Wars       63
# 1058  2015          Star Wars       69
# 964   2014            Technic      116
# 867   2013          Star Wars       41
# 757   2012            Ninjago       47
# 679   2011            Ninjago       43
# 598   2010          Key Chain       44
# 545   2009             Racers       42
# 433   2008           Bionicle       39
# 393   2007          Key Chain       36
# 303   2006           Bionicle       50
# 240   2005           Bionicle       36
# 183   2004           Bionicle       47
# 118   2003           Bionicle       63
# 103   2002            Technic       65
# 7     2001           Bionicle       45

# %% [markdown]
# #### 7.) What is the most produced color of lego ever in terms of quantity of parts?

# %%
colors = pd.read_csv('colors.csv')
colors
# Out:
#        id                  name     rgb is_trans
# 0      -1             [Unknown]  0033B2        f
# 1       0                 Black  05131D        f
# 2       1                  Blue  0055BF        f
# 3       2                 Green  237841        f
# 4       3        Dark Turquoise  008F9B        f
# ..    ...                   ...     ...      ...
# 218  1092       Metallic Copper  764D3B        f
# 219  1093           Light Lilac  9195CA        f
# 220  1094   Trans-Medium Purple  8D73B3        f
# 221  1095           Trans-Black  635F52        t
# 222  9999  [No Color/Any Color]  05131D        f
#
# [223 rows x 4 columns]

# %%
inventory_parts = pd.read_csv('inventory_parts.csv')
inventory_parts
# Out:
#          inventory_id        part_num  color_id  quantity is_spare  \
# 0                   1        48379c01        72         1        f
# 1                   1           48395         7         1        f
# 2                   1  stickerupn0077      9999         1        f
# 3                   1         upn0342         0         1        f
# 4                   1         upn0350        25         1        f
# ...               ...             ...       ...       ...      ...
# 1144003        178341     92198pr0349        70         1        f
# 1144004        178342   2277c01pr0008         3         1        f
# 1144005        178342           90396       226         1        f
# 1144006        178342     92198pr0392        92         1        f
# 1144007        178342  92456c03pr0008        92         1        f
#
#                                                    img_url
# 0        https://cdn.rebrickable.com/media/parts/photos...
# 1        https://cdn.rebrickable.com/media/parts/photos...
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1144003  https://cdn.rebrickable.com/media/parts/elemen...
# 1144004  https://cdn.rebrickable.com/media/parts/elemen...
# 1144005  https://cdn.rebrickable.com/media/parts/elemen...
# 1144006  https://cdn.rebrickable.com/media/parts/elemen...
# 1144007  https://cdn.rebrickable.com/media/parts/elemen...
#
# [1144008 rows x 6 columns]

# %% [markdown]
# #### Note - Join two datasets to answer question

# %%
color_inventory = pd.merge(inventory_parts, colors, how = 'left', left_on = 'color_id', right_on = 'id')
color_inventory
# Out:
#          inventory_id        part_num  color_id  quantity is_spare  \
# 0                   1        48379c01        72         1        f
# 1                   1           48395         7         1        f
# 2                   1  stickerupn0077      9999         1        f
# 3                   1         upn0342         0         1        f
# 4                   1         upn0350        25         1        f
# ...               ...             ...       ...       ...      ...
# 1144003        178341     92198pr0349        70         1        f
# 1144004        178342   2277c01pr0008         3         1        f
# 1144005        178342           90396       226         1        f
# 1144006        178342     92198pr0392        92         1        f
# 1144007        178342  92456c03pr0008        92         1        f
#
#                                                    img_url    id  \
# 0        https://cdn.rebrickable.com/media/parts/photos...    72
# 1        https://cdn.rebrickable.com/media/parts/photos...     7
# 2                                                      NaN  9999
# 3                                                      NaN     0
# 4                                                      NaN    25
# ...                                                    ...   ...
# 1144003  https://cdn.rebrickable.com/media/parts/elemen...    70
# 1144004  https://cdn.rebrickable.com/media/parts/elemen...     3
# 1144005  https://cdn.rebrickable.com/media/parts/elemen...   226
# 1144006  https://cdn.rebrickable.com/media/parts/elemen...    92
# 1144007  https://cdn.rebrickable.com/media/parts/elemen...    92
#
#                          name     rgb is_trans
# 0            Dark Bluish Gray  6C6E68        f
# 1                  Light Gray  9BA19D        f
# 2        [No Color/Any Color]  05131D        f
# 3                       Black  05131D        f
# 4                      Orange  FE8A18        f
# ...                       ...     ...      ...
# 1144003         Reddish Brown  582A12        f
# 1144004        Dark Turquoise  008F9B        f
# 1144005   Bright Light Yellow  FFF03A        f
# 1144006                Nougat  D09168        f
# 1144007                Nougat  D09168        f
#
# [1144008 rows x 10 columns]

# %%
color_inventory.rename(columns={'name': 'color_name'}, inplace = True)

# %%
color_inventory
# Out:
#          inventory_id        part_num  color_id  quantity is_spare  \
# 0                   1        48379c01        72         1        f
# 1                   1           48395         7         1        f
# 2                   1  stickerupn0077      9999         1        f
# 3                   1         upn0342         0         1        f
# 4                   1         upn0350        25         1        f
# ...               ...             ...       ...       ...      ...
# 1144003        178341     92198pr0349        70         1        f
# 1144004        178342   2277c01pr0008         3         1        f
# 1144005        178342           90396       226         1        f
# 1144006        178342     92198pr0392        92         1        f
# 1144007        178342  92456c03pr0008        92         1        f
#
#                                                    img_url    id  \
# 0        https://cdn.rebrickable.com/media/parts/photos...    72
# 1        https://cdn.rebrickable.com/media/parts/photos...     7
# 2                                                      NaN  9999
# 3                                                      NaN     0
# 4                                                      NaN    25
# ...                                                    ...   ...
# 1144003  https://cdn.rebrickable.com/media/parts/elemen...    70
# 1144004  https://cdn.rebrickable.com/media/parts/elemen...     3
# 1144005  https://cdn.rebrickable.com/media/parts/elemen...   226
# 1144006  https://cdn.rebrickable.com/media/parts/elemen...    92
# 1144007  https://cdn.rebrickable.com/media/parts/elemen...    92
#
#                    color_name     rgb is_trans
# 0            Dark Bluish Gray  6C6E68        f
# 1                  Light Gray  9BA19D        f
# 2        [No Color/Any Color]  05131D        f
# 3                       Black  05131D        f
# 4                      Orange  FE8A18        f
# ...                       ...     ...      ...
# 1144003         Reddish Brown  582A12        f
# 1144004        Dark Turquoise  008F9B        f
# 1144005   Bright Light Yellow  FFF03A        f
# 1144006                Nougat  D09168        f
# 1144007                Nougat  D09168        f
#
# [1144008 rows x 10 columns]

# %%
Popular_Color = color_inventory.groupby('color_name').sum().reset_index()
Popular_Color = Popular_Color[['color_name', 'quantity']].sort_values('quantity', ascending = False)

Popular_Color.head(10).plot(kind='bar', x='color_name', y='quantity')
# Out:
# <AxesSubplot:xlabel='color_name'>
